# %%
# import packages

from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_state_qsphere
from qiskit.visualization import plot_bloch_multivector, plot_bloch_multivector, plot_histogram
from qiskit import transpile
import matplotlib.pyplot as plt
import numpy as np

# %%
def state_eval(quantum_circuit):
    """ 
    Evaluates a 3-qubit circuit and prints the full quantum state including superpositions and phases
    """
    print(f"{'Input':<10} | {'Output State Vector'}")
    print("-" * 50)

    for i in range(8):
        # 1. Prepare Input
        qc_init = QuantumCircuit(3)
        input_str = format(i, '03b')
        
        for qubit_index, bit in enumerate(reversed(input_str)):
            if bit == '1':
                qc_init.x(qubit_index)
        
        # 2. Run Circuit
        full_circuit = qc_init.compose(quantum_circuit)
        state = Statevector(full_circuit)
        
        # 3. Get Amplitudes (Key Change)
        # to_dict() returns { '000': (0.707+0j), ... } for non-zero states only
        raw_dict = state.to_dict()
        
        # 4. Format the output string
        state_parts = []
        for basis_state, amp in raw_dict.items():
            # Clean up the complex number for printing
            # If imaginary part is tiny, ignore it. 
            if np.isclose(amp.imag, 0):
                amp_str = f"{amp.real:.3f}" # e.g., "0.707"
            else:
                amp_str = f"{amp:.2f}"      # e.g., "(0.70+0.70j)"
            
            state_parts.append(f"{amp_str}|{basis_state}>")
        
        # Join them with " + "
        output_str = " + ".join(state_parts)
        
        print(f"{input_str:<10} | {output_str}")

# %%
# initialize the equivalent (trial) quantum circuit decomposition of tofollio gate 

qc_toffoli_trial = QuantumCircuit(3)
qc_toffoli_trial.h(0)
qc_toffoli_trial.cx(1, 0)
qc_toffoli_trial.tdg(0)
qc_toffoli_trial.cx(2, 0)
qc_toffoli_trial.t(0)
qc_toffoli_trial.cx(1, 0)
qc_toffoli_trial.tdg(0)
qc_toffoli_trial.cx(2, 0)
qc_toffoli_trial.barrier()
qc_toffoli_trial.t(0)
qc_toffoli_trial.tdg(1)
qc_toffoli_trial.barrier()
qc_toffoli_trial.h(0)
qc_toffoli_trial.cx(1, 2)
qc_toffoli_trial.tdg(1)
qc_toffoli_trial.cx(1, 2)
qc_toffoli_trial.s(1)
qc_toffoli_trial.t(2)

state_eval(qc_toffoli_trial)
display(qc_toffoli_trial.draw(output='mpl'))
# Out:
# Input      | Output State Vector
# --------------------------------------------------
# |000>      | 1.000|000> + 0.000|001>
# |001>      | 1.000|010> + 0.000|011>
# |010>      | 0.71+0.71j|100> + 0.000|101>
# |011>      | 0.000|110> + 0.71-0.71j|111>
# ---------------------------------------------------------------------------
# CircuitError                              Traceback (most recent call last)
# Cell In[35], line 23
#      20 qc_toffoli_trial.s(1)
#      21 qc_toffoli_trial.t(2)
# ---> 23 state_eval(qc_toffoli_trial)
#      24 display(qc_toffoli_trial.draw(output='mpl'))
#
# Cell In[33], line 15, in state_eval(quantum_circuit)
#      13 for qubit_index, bit in enumerate(reversed(input_str)):
#      14     if bit == '1':
# ---> 15         qc_init.x(qubit_index)
#      17 # 2. Run Circuit
#      18 full_circuit = qc_init.compose(quantum_circuit)
#
# File ~\anaconda3\envs\qiskit-env\lib\site-packages\qiskit\circuit\quantumcircuit.py:6107, in QuantumCircuit.x(self, qubit, label)
#    6095 def x(self, qubit: QubitSpecifier, label: str | None = None) -> InstructionSet:
#    6096     r"""Apply :class:`~qiskit.circuit.library.XGate`.
#    6097
#    6098     For the full matrix form of this gate, see the underlying gate documentation.
#    (...)
#    6105         A handle to the instructions created.
#    6106     """
# -> 6107     return self._append_standard_gate(StandardGate.X, [qubit], (), label=label)
#
# File ~\anaconda3\envs\qiskit-env\lib\site-packages\qiskit\circuit\quantumcircuit.py:2748, in QuantumCircuit._append_standard_gate(self, op, qargs, params, label)
#    2745 if params is None:
#    2746     params = []
# -> 2748 expanded_qargs = [self._qbit_argument_conversion(qarg) for qarg in qargs or []]
#    2749 for param in params:
#    2750     Gate.validate_parameter(op, param)
#
# File ~\anaconda3\envs\qiskit-env\lib\site-packages\qiskit\circuit\quantumcircuit.py:2748, in <listcomp>(.0)
#    2745 if params is None:
#    2746     params = []
# -> 2748 expanded_qargs = [self._qbit_argument_conversion(qarg) for qarg in qargs or []]
#    2749 for param in params:
#    2750     Gate.validate_parameter(op, param)
#
# File ~\anaconda3\envs\qiskit-env\lib\site-packages\qiskit\circuit\quantumcircuit.py:2720, in QuantumCircuit._qbit_argument_conversion(self, qubit_representation)
#    2709 def _qbit_argument_conversion(self, qubit_representation: QubitSpecifier) -> list[Qubit]:
#    2710     """
#    2711     Converts several qubit representations (such as indexes, range, etc.)
#    2712     into a list of qubits.
#    (...)
#    2718         The resolved instances of the qubits.
#    2719     """
# -> 2720     return self._data._qbit_argument_conversion(qubit_representation)
#
# CircuitError: 'Index 3 out of range for size 3.'

# %% [markdown]
# Trial Circuit generates correct Toffoli up to a relative phase

# %%
print(f"{'Input (q2 q1 q0)':<16} | {'Output (q2 q1 q0)':<16}")
print("-" * 35)

for i in range(8):
    qc_init = QuantumCircuit(3)
    input_str = format(i, '03b')

    for qubit_index, bit in enumerate(reversed(input_str)):
        if bit == '1':
            qc_init.x(qubit_index)

    full_circuit = qc_init.compose(qc_toffoli_trial)
    
    final_state = Statevector(full_circuit)
    
    counts = final_state.probabilities_dict()
    output_str = list(counts.keys())[0]
    
    print(f"{input_str:<16} | {output_str:<16}")
# Out:
# Input (q2 q1 q0) | Output (q2 q1 q0)
# -----------------------------------
# 000              | 000
# 001              | 000
# 010              | 010
# 011              | 010
# 100              | 100
# 101              | 100
# 110              | 110
# 111              | 110

# %%
qc_toffoli_perfect = QuantumCircuit(3)
qc_toffoli_perfect.ccx(2, 1, 0) # Control on 2, 1; Target on 0

# 2. Decompose it into basis gates (u, cx)
# If you specifically need H, T, CX, you can transpile:

qc_toffoli_transpiled = transpile(qc_toffoli_perfect, basis_gates=['s', 'cx', 'h', 't', 'tdg'])
display(qc_toffoli_transpiled.draw(output='mpl'))

state_eval(qc_toffoli_transpiled)
# Out:
# Input      | Output State Vector
# --------------------------------------------------
# 000        | 1.000|000> + 0.000|001>
# 001        | 0.000|000> + 1.000|001>
# 010        | 1.000|010> + 0.000|011>
# 011        | 0.000|010> + 1.000|011>
# 100        | 1.000|100> + 0.000|101>
# 101        | 0.000|100> + 1.000|101>
# 110        | 0.000|110> + 1.000|111>
# 111        | 1.000|110> + 0.000|111>
